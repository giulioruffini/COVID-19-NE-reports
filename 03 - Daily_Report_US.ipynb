# %% [markdown]
# ![](./images/logo.png)
# # COVID19 Model - Daily Report US
#
# ---
#
# **Neuroelectrics research team**
# March 2020
# Main Authors: G Ruffini and R Sanchez-Todo and MC Biagi
#
# Curator: G. Ruffini
#
# Contributors: E Lleal
#
# ---

# %%
# %matplotlib inline
from ne_epidemic.utilities import sir_prediction_from_country
sir_prediction_from_country('US')
# Out:
# Today's date: 2020-04-02
#
# Country:  US
# - UCI database:  https://sccm.org/Blog/March-2020/United-States-Resource-Availability-for-COVID-19
# - Total UCI beds:  96596
# - Fatalities database:  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# - First day with more than 5 casualties (m/d/y):  3 / 2 / 2020
# - Days since first fatalities:  31
# - Last day with data: 4/1/20
# - US fatalities to date: 4757
#
#
# Model Initial parameters:
# - Initial simulation day is March:  2020-03-02
# - Infection to death latency (days):  11
#
# Intervention list:
# day since start simulation: 12  => beta reduction factor: 0.87
# day since start simulation: 37  => beta reduction factor: 0.48
#
# Fitting parameters N0 and beta
# Initial loss: 764320
# Optimization terminated successfully.
#          Current function value: 142.314717
#          Iterations: 117
#          Function evaluations: 223
# Estimated parameters:
# N0: 1412
# beta0 (contacts per day): 0.46
# R0: 2.32
#
# Final loss: 142
# Initial/Final % loss: 0.02
# Normalized Loss (per million persons, per day) 0.014
#
#
# _____________________________________________________________________
#
# MODEL PARAMETERS:
#
# Model name: optimized 2 pars
#
# Simulated days: 61.0
# Initially infected/Total population (N0/N): 1412/327200000 (0.4 per 100,000)
# beta (per day): 0.5 , nu (per day): 0.2
# 1/beta (days): 2.2 , 1/nu (days): 5.0
# IFR: 0.002
# Initial Doubling time: 2.6  days, Initial R0: 2.3
# Interventions:
#   1/beta at day 12.0  = 2.5  days, R0 = 2.02
#   1/beta at day 37.0  = 4.5  days, R0 = 1.11
# Latency for intervention effect on fatalities (days): 11
# Infected_to_Detected_ratio: 5
#
# Percent of population exposed at end simulation: 47%
# Peak ICU admissions:  106927  on day 2020-04-19
# (note model does not account for long ICU stays)
# Total fatalities at end of simulation (61 days):  278382
#
# Today's model outputs:
#    Infected: 3077227 (0.9%)
#    Recovered: 2934138 (0.9%)
#    Exposed to date: 6011365 (1.8%)
#    In ICU: 7693
#    Fatalities: 5868
# Note: a quadratic fit is carried out on the last days of log2(fatality data).
#       The derivative of the quadratic is used to estimate doubling time and R(t).
# Rt estimated from doubling time using nu= 0.2
#
# Run finished 2020-04-02 15:51:04.260637
