# %% [markdown]
# # JHU datagrabber
# Neuroelectrics research team, March 2020
#
# v0.2 G. Ruffini, R. Sanchez-Todo
#
# This is a book to grab data from JHU and plot it for some countries, estimating also Rt and doubling times using a simple logfit of the last 7 days.

# %%
from ne_epidemic.utilities import data_grabber_JHU
from ne_epidemic.param_estimate import get_doubling_time

# %% [markdown]
# # Spain

# %%
df, firstdate = data_grabber_JHU(country="Spain")
_ = get_doubling_time(df, nu=1/5, ndays=7)
# Out:
# - Fatalities database:  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# - First day with more than 5 casualties (m/d/y):  3 / 7 / 2020
# - Days since first fatalities:  25
# - Last day with data: 3/31/20
# - Spain fatalities to date: 8464
# Note: a quadratic fit is carried out on the last days of log2(fatality data).
#       The derivative of the quadratic is used to estimate doubling time and R(t).
# Rt estimated from doubling time using nu= 0.2

# %% [markdown]
# # Italy

# %%
df, firstdate = data_grabber_JHU(country="Italy")
_ = get_doubling_time(df, nu=1/5, ndays=7)
# Out:
# - Fatalities database:  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# - First day with more than 5 casualties (m/d/y):  2 / 24 / 2020
# - Days since first fatalities:  37
# - Last day with data: 3/31/20
# - Italy fatalities to date: 12428
# Note: a quadratic fit is carried out on the last days of log2(fatality data).
#       The derivative of the quadratic is used to estimate doubling time and R(t).
# Rt estimated from doubling time using nu= 0.2

# %% [markdown]
# # Portugal

# %%
df, firstdate = data_grabber_JHU(country="Portugal")
_ = get_doubling_time(df, nu=1/5, ndays=7)
# Out:
# - Fatalities database:  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# - First day with more than 5 casualties (m/d/y):  3 / 20 / 2020
# - Days since first fatalities:  12
# - Last day with data: 3/31/20
# - Portugal fatalities to date: 160
# Note: a quadratic fit is carried out on the last days of log2(fatality data).
#       The derivative of the quadratic is used to estimate doubling time and R(t).
# Rt estimated from doubling time using nu= 0.2

# %% [markdown]
# # France

# %%
df, firstdate = data_grabber_JHU(country="France")
_ = get_doubling_time(df, nu=1/5, ndays=7)
# Out:
# - Fatalities database:  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# - First day with more than 5 casualties (m/d/y):  3 / 5 / 2020
# - Days since first fatalities:  27
# - Last day with data: 3/31/20
# - France fatalities to date: 3523
# Note: a quadratic fit is carried out on the last days of log2(fatality data).
#       The derivative of the quadratic is used to estimate doubling time and R(t).
# Rt estimated from doubling time using nu= 0.2

# %% [markdown]
# # United States

# %%
df, firstdate = data_grabber_JHU(country="US")
_ = get_doubling_time(df, nu=1/5, ndays=7)
# Out:
# - Fatalities database:  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# - First day with more than 5 casualties (m/d/y):  3 / 2 / 2020
# - Days since first fatalities:  30
# - Last day with data: 3/31/20
# - US fatalities to date: 3873
# Note: a quadratic fit is carried out on the last days of log2(fatality data).
#       The derivative of the quadratic is used to estimate doubling time and R(t).
# Rt estimated from doubling time using nu= 0.2
